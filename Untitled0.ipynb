# %% [markdown]
# <a href="https://colab.research.google.com/github/manavghosh123/datasci_project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Driving the Transition: Analyzing Electric Vehicle Transportation
#
#
# The transition to electric vehicles (EVs) is a central strategy in the effort to reduce dependence on oil. However, the adoption of EVs varies significantly by geography, income, vehicle type, and access to charging infrastructure. State-level data offers valuable insight into the pace and pattern of this transition.
# This project invites students to explore the population of electric vehicles registered in Washington State. By analyzing vehicle registration data, students will investigate where EV adoption is most common, which vehicle types dominate the market, and how electric range and pricing correlate with geographic and demographic indicators. This dataset provides a rich opportunity to examine the intersection of clean energy policy, transportation infrastructure, and environmental equity.

# %%
import zipfile
import pandas as pd

zip_path = "datasets/Electric Vehicle Adoption Dataset/Electric_Vehicle_Population_Data.csv.zip"

with zipfile.ZipFile(zip_path) as z:
    df = pd.read_csv(z.open("Electric_Vehicle_Population_Data.csv"))

# Clean column names
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("(", "", regex=False)
    .str.replace(")", "", regex=False)
    .str.replace("-", "_")
)

df.head()
# Out:
#      vin_1_10     county          city state  postal_code  model_year   make  \
# 0  YV4H60PE7S     Kitsap     Bremerton    WA      98310.0        2025  VOLVO
# 1  5YJ3E1EB3K  Snohomish      Lynnwood    WA      98087.0        2019  TESLA
# 2  1FADP5CUXD     Kitsap  Port Orchard    WA      98367.0        2013   FORD
# 3  5YJSA1H20E   Thurston          Yelm    WA      98597.0        2014  TESLA
# 4  7SAYGDEE2P  Snohomish       Bothell    WA      98012.0        2023  TESLA
#
#      model                   electric_vehicle_type  \
# 0     XC90  Plug-in Hybrid Electric Vehicle (PHEV)
# 1  MODEL 3          Battery Electric Vehicle (BEV)
# 2    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  MODEL S          Battery Electric Vehicle (BEV)
# 4  MODEL Y          Battery Electric Vehicle (BEV)
#
#      clean_alternative_fuel_vehicle_cafv_eligibility  electric_range  \
# 0            Clean Alternative Fuel Vehicle Eligible            32.0
# 1            Clean Alternative Fuel Vehicle Eligible           220.0
# 2              Not eligible due to low battery range            19.0
# 3            Clean Alternative Fuel Vehicle Eligible           208.0
# 4  Eligibility unknown as battery range has not b...             0.0
#
#    legislative_district  dol_vehicle_id             vehicle_location  \
# 0                  23.0       277607004   POINT (-122.61136 47.5752)
# 1                  21.0       478641796  POINT (-122.27981 47.85727)
# 2                  35.0       253249678  POINT (-122.68471 47.50524)
# 3                   2.0       131872905  POINT (-122.60735 46.94239)
# 4                   1.0       260935657  POINT (-122.20105 47.84423)
#
#          electric_utility  2020_census_tract
# 0  PUGET SOUND ENERGY INC       5.303508e+10
# 1  PUGET SOUND ENERGY INC       5.306104e+10
# 2  PUGET SOUND ENERGY INC       5.303509e+10
# 3  PUGET SOUND ENERGY INC       5.306701e+10
# 4  PUGET SOUND ENERGY INC       5.306105e+10

# %%
df.isnull().sum()
# Out:
# vin_1_10                                             0
# county                                               9
# city                                                 9
# state                                                0
# postal_code                                          9
# model_year                                           0
# make                                                 0
# model                                                0
# electric_vehicle_type                                0
# clean_alternative_fuel_vehicle_cafv_eligibility      0
# electric_range                                       9
# legislative_district                               740
# dol_vehicle_id                                       0
# vehicle_location                                    16
# electric_utility                                     9
# 2020_census_tract                                    9
# dtype: int64

# %%
# delete rows that are empty
df = df.dropna()

# make sure no missing values left
df.isnull().sum()
# Out:
# vin_1_10                                           0
# county                                             0
# city                                               0
# state                                              0
# postal_code                                        0
# model_year                                         0
# make                                               0
# model                                              0
# electric_vehicle_type                              0
# clean_alternative_fuel_vehicle_cafv_eligibility    0
# electric_range                                     0
# legislative_district                               0
# dol_vehicle_id                                     0
# vehicle_location                                   0
# electric_utility                                   0
# 2020_census_tract                                  0
# dtype: int64

# %%
# check for duplicate rows
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
# double check
df.info()

print("\nDataset shape:", df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 287007 entries, 0 to 287761
# Data columns (total 16 columns):
#  #   Column                                           Non-Null Count   Dtype
# ---  ------                                           --------------   -----
#  0   vin_1_10                                         287007 non-null  object
#  1   county                                           287007 non-null  object
#  2   city                                             287007 non-null  object
#  3   state                                            287007 non-null  object
#  4   postal_code                                      287007 non-null  float64
#  5   model_year                                       287007 non-null  int64
#  6   make                                             287007 non-null  object
#  7   model                                            287007 non-null  object
#  8   electric_vehicle_type                            287007 non-null  object
#  9   clean_alternative_fuel_vehicle_cafv_eligibility  287007 non-null  object
#  10  electric_range                                   287007 non-null  float64
#  11  legislative_district                             287007 non-null  float64
#  12  dol_vehicle_id                                   287007 non-null  int64
#  13  vehicle_location                                 287007 non-null  object
#  14  electric_utility                                 287007 non-null  object
#  15  2020_census_tract                                287007 non-null  float64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 37.2+ MB
#
# Dataset shape: (287007, 16)

# %%
# double check row is vehicle and column is variable
print("Rows (observations):", len(df))
print("Columns (variables):", len(df.columns))

print("\nColumn Names:")
print(df.columns.tolist())
# Out:
# Rows (observations): 287007
# Columns (variables): 16
#
# Column Names:
# ['vin_1_10', 'county', 'city', 'state', 'postal_code', 'model_year', 'make', 'model', 'electric_vehicle_type', 'clean_alternative_fuel_vehicle_cafv_eligibility', 'electric_range', 'legislative_district', 'dol_vehicle_id', 'vehicle_location', 'electric_utility', '2020_census_tract']
